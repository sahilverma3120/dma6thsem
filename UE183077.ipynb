# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("/Users/prabhavvalecha/Downloads/RockMine.csv.csv - RockMine.csv.csv.csv",header=None)
print(data)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
b=len(data.columns)

# %%
a=[]
for i in range(1,len(data.columns)+1):
    a.append("C"+str(i))

# %%
a
# Out:
# ['C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C28',
#  'C29',
#  'C30',
#  'C31',
#  'C32',
#  'C33',
#  'C34',
#  'C35',
#  'C36',
#  'C37',
#  'C38',
#  'C39',
#  'C40',
#  'C41',
#  'C42',
#  'C43',
#  'C44',
#  'C45',
#  'C46',
#  'C47',
#  'C48',
#  'C49',
#  'C50',
#  'C51',
#  'C52',
#  'C53',
#  'C54',
#  'C55',
#  'C56',
#  'C57',
#  'C58',
#  'C59',
#  'C60',
#  'C61']

# %%
data.columns=a

# %%
data.head()
df3=data["C61"]

# %%
for i in a:
    print(data[i].nunique())
# Out:
# 177
# 182
# 190
# 181
# 193
# 196
# 195
# 201
# 205
# 207
# 203
# 206
# 198
# 202
# 203
# 203
# 202
# 204
# 206
# 203
# 200
# 203
# 199
# 201
# 198
# 194
# 190
# 194
# 197
# 202
# 207
# 205
# 205
# 206
# 205
# 205
# 206
# 206
# 204
# 206
# 204
# 208
# 205
# 196
# 205
# 199
# 202
# 204
# 193
# 154
# 160
# 144
# 134
# 134
# 129
# 122
# 121
# 124
# 119
# 109
# 2

# %%
get_unique=data.nunique()
df2=get_unique.sort_values().index
df2=list(df2)

df2.remove("C61")
print(df2)

data= data[df2]

data
# Out:
# ['C60', 'C59', 'C57', 'C56', 'C58', 'C55', 'C54', 'C53', 'C52', 'C50', 'C51', 'C1', 'C4', 'C2', 'C3', 'C27', 'C5', 'C49', 'C28', 'C26', 'C7', 'C6', 'C44', 'C29', 'C13', 'C25', 'C46', 'C23', 'C21', 'C24', 'C8', 'C47', 'C17', 'C14', 'C30', 'C11', 'C22', 'C16', 'C15', 'C20', 'C48', 'C39', 'C41', 'C18', 'C33', 'C43', 'C36', 'C35', 'C32', 'C45', 'C9', 'C37', 'C40', 'C38', 'C34', 'C12', 'C19', 'C10', 'C31', 'C42']
#         C60     C59     C57     C56     C58     C55     C54     C53     C52  \
# 0    0.0032  0.0090  0.0180  0.0167  0.0084  0.0072  0.0159  0.0065  0.0027
# 1    0.0044  0.0052  0.0140  0.0191  0.0049  0.0094  0.0048  0.0089  0.0084
# 2    0.0078  0.0095  0.0316  0.0244  0.0164  0.0180  0.0095  0.0166  0.0232
# 3    0.0117  0.0040  0.0050  0.0073  0.0044  0.0085  0.0150  0.0036  0.0121
# 4    0.0094  0.0107  0.0072  0.0015  0.0048  0.0110  0.0105  0.0054  0.0031
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# ...

# %%
data=data[data.columns[:b-10]]

# %%
data.head()
# Out:
#       C60     C59     C57     C56     C58     C55     C54     C53     C52  \
# 0  0.0032  0.0090  0.0180  0.0167  0.0084  0.0072  0.0159  0.0065  0.0027
# 1  0.0044  0.0052  0.0140  0.0191  0.0049  0.0094  0.0048  0.0089  0.0084
# 2  0.0078  0.0095  0.0316  0.0244  0.0164  0.0180  0.0095  0.0166  0.0232
# 3  0.0117  0.0040  0.0050  0.0073  0.0044  0.0085  0.0150  0.0036  0.0121
# 4  0.0094  0.0107  0.0072  0.0015  0.0048  0.0110  0.0105  0.0054  0.0031
#
#       C50  ...     C39     C41     C18     C33     C43     C36     C35  \
# 0  0.0324  ...  0.4943  0.0510  0.2999  0.5121  0.2825  0.8507  0.8537
# 1  0.0061  ...  0.1840  0.1674  0.8874  0.1984  0.1401  0.4182  0.1306
# 2  0.0106  ...  0.5375  0.4647  0.7551  0.1862  0.2129  0.3043  0.4232
# 3  0.0294  ...  0.9857  0.6121  0.2281  0.6120  0.3210  0.3012  0.3953
# 4  0.0046  ...  0.2828  0.1979  0.6193  0.2881  0.1847  0.4181  0.1951
#
#       C32     C45      C9
# 0  0.2604  0.2641  0.3109
# 1  0.2947  0.0621  0.3337
# ...

# %%
# a=data.columns
# for i in a:
#     m=data[i].mean()
#     s=data[i].std()
#     data[i]=(data[i]-m)%s
for i in data:
  m=data[i].mean()
  std=data[i].std()
  data[i]=(data[i]-mean)/std
print(data)
# Out:
#           C60       C59       C57       C56       C58       C55       C54  \
# 0   -0.449315 -1.204529  0.938327 -0.148977 -1.412675  0.715669  0.492517
# 1    0.368649  0.119679 -1.411258  1.273738  0.234879 -1.663146 -1.297839
# 2   -0.743130 -0.926495 -1.268219  1.015213 -0.563801 -0.927074  0.917017
# 3   -1.514091 -0.547601  0.098932  1.079431 -0.042501  1.348380  0.068395
# 4    0.347489 -0.259215  1.391204  1.041557  0.179403 -0.884425  1.388264
# ..        ...       ...       ...       ...       ...       ...       ...
# 203  1.212456  1.085697  0.980026 -0.661089  0.307087 -1.182466 -1.062975
# 204 -1.492931  0.675745 -0.840902  0.486633 -0.708216  0.277638 -0.638474
# 205 -0.517479  1.509845 -1.411258 -1.372447  1.583039  0.228967 -1.156465
# 206  0.641304 -0.770028 -0.840902 -1.173202  1.899165 -1.036455 -1.062595
# 207  1.778926  0.620138 -0.488464  0.368074 -0.486311 -0.890445 -1.344964
#
#           C53       C52       C50  ...       C39       C41       C18  \
# ...

# %%
data.head()
# Out:
#         C60       C59       C57       C56       C58       C55       C54  \
# 0 -0.449315 -1.204529  0.938327 -0.148977 -1.412675  0.715669  0.492517
# 1  0.368649  0.119679 -1.411258  1.273738  0.234879 -1.663146 -1.297839
# 2 -0.743130 -0.926495 -1.268219  1.015213 -0.563801 -0.927074  0.917017
# 3 -1.514091 -0.547601  0.098932  1.079431 -0.042501  1.348380  0.068395
# 4  0.347489 -0.259215  1.391204  1.041557  0.179403 -0.884425  1.388264
#
#         C53       C52       C50  ...       C39       C41       C18       C33  \
# 0 -0.328844  1.295748  1.146855  ...  1.235870  0.213637 -0.401618 -0.341623
# 1  0.797227 -0.080532  1.391271  ... -0.741246 -0.889174  0.469141  1.384317
# 2  1.097354 -1.643623 -0.783510  ... -1.534919 -1.794670 -1.318553  1.172324
# 3  1.623171  1.213889  0.434980  ... -0.645228  1.176471 -1.371810  1.394295
# 4 -0.844960  1.435685  1.035333  ...  1.014998 -0.274386  0.380356 -0.645488
#
#         C43       C36       C35       C32       C45        C9
# ...

# %%
import random
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

A = data
b = df3
A_train, A_test, b_train, b_test = train_test_split(A, b, test_size=0.4,random_state=4)

knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(A_train, b_train)

b_pred=knn.predict(A_test)
print(metrics.accuracy_score(b_test, b_pred))
# Out:
# 0.4523809523809524

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My Drive/8BLOCKS/
# Out:
# /content/gdrive/My Drive/8BLOCKS

# %%
ls
# Out:
# 'RAHUL KUMAR_BLOCKCHAIN.mp4'   RockMine.csv

# %%
import pandas as pd
newe = pd.read_csv("RockMine.csv")
lf = newe

# %%
lf
# Out:
#        0.02  0.0371  0.0428  0.0207  0.0954  ...   0.018  0.0084   0.009  0.0032  R
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044  R
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078  R
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117  R
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094  R
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062  R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ... ..
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157  M
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067  M
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031  M
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048  M
# ...

# %% [markdown]
# **a. Add a column header by giving name to columns as C1, C2, .....**

# %%
col=[]
s="C";
for i in range(1,62):
  col.append(s+str(i))

lf.columns = col
lf
# Out:
#          C1      C2      C3      C4      C5  ...     C57     C58     C59     C60  C61
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044    R
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078    R
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117    R
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094    R
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062    R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ...  ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157    M
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067    M
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031    M
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048    M
# ...

# %% [markdown]
# **b. Sort its columns(except last label column) in increasing order of 'No.of distinct values'.**

# %%
get_unique=lf.nunique()
lf2=get_unique.sort_values().index
lf2=list(lf2)
lf2.remove('C61')

lf=lf[lf2]

# %%
df
# Out:
#          C1      C2      C3      C4      C5  ...     C57     C58     C59     C60  C61
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044    R
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078    R
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117    R
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094    R
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062    R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ...  ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157    M
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067    M
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031    M
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048    M
# ...

# %% [markdown]
# **c. Remove the last 10 columns from the database.**

# %%
lf2=lf2[:-10]
lf2.append('C61')
lf=newe[lf2]
lf
# Out:
#         C60     C59     C57     C56     C58  ...     C36     C35     C32     C45  C61
# 0    0.0044  0.0052  0.0140  0.0191  0.0049  ...  0.4182  0.1306  0.2947  0.0621    R
# 1    0.0078  0.0095  0.0316  0.0244  0.0164  ...  0.3043  0.4232  0.5045  0.2111    R
# 2    0.0117  0.0040  0.0050  0.0073  0.0044  ...  0.3012  0.3953  0.7340  0.4295    R
# 3    0.0094  0.0107  0.0072  0.0015  0.0048  ...  0.4181  0.1951  0.5459  0.0692    R
# 4    0.0062  0.0051  0.0057  0.0089  0.0027  ...  0.2856  0.1407  0.4778  0.1192    R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ...  ...
# 202  0.0157  0.0193  0.0065  0.0101  0.0115  ...  0.0608  0.0849  0.5547  0.0902    M
# 203  0.0067  0.0062  0.0034  0.0063  0.0032  ...  0.1297  0.0928  0.7117  0.0954    M
# 204  0.0031  0.0077  0.0140  0.0089  0.0138  ...  0.1446  0.1098  0.7305  0.0910    M
# 205  0.0048  0.0036  0.0034  0.0035  0.0079  ...  0.0364  0.0776  0.4961  0.1319    M
# ...

# %% [markdown]
# **d. Normalize other columns by subtracting each value from Mean value and dividing by Mean standard deviation.**

# %%
label = lf['C61']
lf.drop(['C61'], axis = 1,inplace=True)

norm_lf=(lf.mean()-lf)/lf.std()
norm_lf
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#           C60       C59       C57  ...       C35       C32       C45
# 0    0.421439  0.441618 -1.082215  ...  1.007710  0.680462  0.887344
# 1   -0.253439 -0.252386 -4.140012  ... -0.127471 -0.302717 -0.093407
# 2   -1.027564  0.635294  0.481432  ... -0.019229 -1.378216 -1.530965
# 3   -0.571028 -0.446062  0.099207  ...  0.757473 -0.496729  0.840611
# 4    0.064151  0.457758  0.359815  ...  0.968526 -0.177594  0.511499
# ..        ...       ...       ...  ...       ...       ...       ...
# 202 -1.821538 -1.834071  0.220824  ...  1.185009 -0.537968  0.702384
# 203 -0.035096  0.280222  0.759414  ...  1.154360 -1.273712  0.668156
# ...

# %% [markdown]
# **e. Run Any classification algorithm on new normalized dataset and report the accuracy.**

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier


X=norm_lf
Y=label
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.6,random_state=2)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (124, 50)
# (124,)
# (83, 50)
# (83,)

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm


X=norm_lf
Y=label
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.6,random_state=2)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

svc_model1 = svm.SVC(C=0.025, kernel='linear')
svc_model1.fit(X_train,Y_train)
score=svc_model1.score(X_test,Y_test)
print(score*100)
# Out:
# (124, 50)
# (124,)
# (83, 50)
# (83,)
# 81.92771084337349

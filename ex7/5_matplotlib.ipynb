# %% [markdown]
# ## Matplotlib
# (c) Naveen Aggarwal

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5,6,7]) 
plt.ylabel('Some significant numbers on Y Axis') 
plt.xlabel('Total Range on X-axis')
plt.show()

# %%
import numpy as np 
# evenly sampled time at .2 intervals 
t = np.arange(0., 5., 0.2) 
# red dashes, blue squares and green triangles 

print(t)
plt.plot(t,t, 'r--')
plt.axis([0, 6, 0, 150]) # x and y range of axis 
plt.show() 
plt.plot(t, t, 'b--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'go-', label='line 1', linewidth=4)
plt.show()

# %% [markdown]
# ### For more information visit the following doc
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
def f(t): 
    return np.exp(-t) * np.cos(2*np.pi*t) 
t1 = np.arange(0.0, 5.0, 0.1) 
t2 = np.arange(0.0, 5.0, 0.02) 
plt.figure(1) # Called implicitly
# for multiple figures 
plt.subplot(121) # 2 rows, 1 column, 1st plot 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k') 
plt.subplot(122) # 2 rows, 1 column, 2nd plot 
plt.plot(t2, np.cos(2*np.pi*t2), 'r--') 
plt.show() 
#%%

# %% [markdown]
# ##### Create a line graph of CO2 versus time. View the plot.

# %%
times = range(7)
co2 = [250, 265, 272, 260, 300, 320, 389]
plt.plot(times, co2)
plt.plot(times, co2, 'b--')
plt.title("Concentration of CO2 versus time")
plt.ylabel("[CO2]")
plt.xlabel("Time (decade)")
plt.show()

# %% [markdown]
# ##### Continuing with the above data plot, add some additional data

# %%
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
plt.plot(times, co2, 'b--', times, temp, 'r*-')
plt.show()
plt.savefig("co2_temp.pdf")

# %% [markdown]
# ##### Multiple axes

# %%
fig, ax1 = plt.subplots()
times = range(8)
co2 = [250, 265, 272, 260, 300, 320, 389, 410]
ax1.plot(times, co2, "b--")
ax1.set_ylabel("[CO2]")
ax2 = ax1.twinx()
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2, 20.8]
ax2.plot(times, temp, "r*-")
ax2.set_ylabel("Temp (degC)")
plt.show()

# %% [markdown]
# ##### Multiple Plots

# %%
plt.subplot(2, 2, 1)
x = range(0, 10, 1)
plt.plot(x)
plt.subplot(2, 2, 2)
y = range(10, 0, -1)
plt.plot(y)
plt.subplot(2, 2, 3)
z = [4] * 10
plt.plot(z)
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
mu, sigma = 100, 25 
x = mu + sigma * np.random.randn(10000) 
# the histogram of the data 
n, bins, patches = plt.hist(x, 50,normed=1, facecolor='b', alpha=0.2) 
plt.xlabel('Smarts') 
plt.ylabel('Probability') 
plt.title('Histogram of IQ') 
plt.text(60, .025, '$\mu=100,\ \sigma=15$', color='r') #TeX equations 
plt.axis([40, 160, 0, 0.04]) 
plt.grid(True) 
plt.show() 
print(n, bins,patches)
# Out:
# [9.86074986e-05 2.46518746e-05 7.39556239e-05 4.93037493e-05
#  1.23259373e-04 2.71170621e-04 3.20474370e-04 4.68385618e-04
#  7.88859988e-04 1.65167560e-03 2.34192809e-03 2.93357308e-03
#  3.69778120e-03 5.07828618e-03 6.18762053e-03 7.37091052e-03
#  8.87467487e-03 1.13891661e-02 1.09454323e-02 1.40515685e-02
#  1.41994798e-02 1.57032441e-02 1.61223260e-02 1.61223260e-02
#  1.48897323e-02 1.40762204e-02 1.34352717e-02 1.21780261e-02
#  1.07975211e-02 9.71283861e-03 7.24765114e-03 6.45879116e-03
#  5.05363430e-03 3.96895182e-03 3.18009183e-03 2.14471309e-03
#  1.55306810e-03 1.35585311e-03 5.66993117e-04 4.19081869e-04
#  2.46518746e-04 1.23259373e-04 4.93037493e-05 7.39556239e-05
#  0.00000000e+00 0.00000000e+00 2.46518746e-05 4.93037493e-05
#  0.00000000e+00 2.46518746e-05] [  6.17482239  10.23130902  14.28779566  18.34428229  22.40076893
#   26.45725556  30.5137422   34.57022883  38.62671547  42.6832021
#   46.73968874  50.79617537  54.85266201  58.90914864  62.96563528
#   67.02212191  71.07860855  75.13509518  79.19158182  83.24806845
#   87.30455509  91.36104172  95.41752836  99.474015   103.53050163
#  107.58698827 111.6434749  115.69996154 119.75644817 123.81293481
#  127.86942144 131.92590808 135.98239471 140.03888135 144.09536798
#  148.15185462 152.20834125 156.26482789 160.32131452 164.37780116
#  168.43428779 172.49077443 176.54726106 180.6037477  184.66023433
#  188.71672097 192.7732076  196.82969424 200.88618088 204.94266751
#  208.99915415] <a list of 50 Patch objects>

# %%
import scipy
import matplotlib.pyplot as plt
import scipy.io.wavfile
sample_rate, X = scipy.io.wavfile.read('congestion.wav')
#print (sample_rate, X.shape )
plt.specgram(X, Fs=sample_rate, xextent=(0,30))
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import librosa as lb
import librosa.display
y, sr = lb.load('congestion.wav')
plt.figure(figsize=(12, 8))
D= lb.amplitude_to_db(lb.stft(y), ref=np.max)
plt.subplot(4, 2, 1)
lb.display.specshow(D, y_axis='linear')
plt.colorbar()
plt.title('Linear-frequency power spectrogram')
plt.show()
# Out:
# D:\ProgramData\Anaconda\lib\site-packages\librosa\display.py:656: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(data.dtype, np.complex):

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# Now let's take a look at how it works with Seaborn. As we will see, Seaborn has many of its own high-level plotting routines, but it can also overwrite Matplotlib's default parameters and in turn get even simple Matplotlib scripts to produce vastly superior output. We can set the style by calling Seaborn's set() method. By convention, Seaborn is imported as sns

# %%
import seaborn as sns
sns.set()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# ### Exploring Seaborn Plots
# The main idea of Seaborn is that it provides high-level commands to create a variety of plot types useful for statistical data exploration, and even some statistical model fitting.
#
# Let's take a look at a few of the datasets and plot types available in Seaborn. Note that all of the following could be done using raw Matplotlib commands (this is, in fact, what Seaborn does under the hood) but the Seaborn API is much more convenient.
#
# #### Histograms, KDE, and densities
# Often in statistical data visualization, all you want is to plot histograms and joint distributions of variables. We have seen that this is relatively straightforward in Matplotlib:

# %% [markdown]
# ### Pair plots
# When you generalize joint plots to datasets of larger dimensions, you end up with pair plots. This is very useful for exploring correlations between multidimensional data, when you'd like to plot all pairs of values against each other.
#
# Lets see the demo this with the well-known Iris dataset, which lists measurements of petals and sepals of three iris species:

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5);

# %% [markdown]
# #### Faceted histograms
# Sometimes the best way to view data is via histograms of subsets. Seaborn's FacetGrid makes this extremely simple. We'll take a look at some data that shows the amount that restaurant staff receive in tips based on various indicator data:

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %% [markdown]
# ### Factor plots
# Factor plots can be useful for this kind of visualization as well. This allows you to view the distribution of a parameter within bins defined by any other parameter:

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill");
